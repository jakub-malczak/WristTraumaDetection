# %% [markdown]
# # Scheduler

# %% [markdown]
# #### Yolo11n

# %%
# !python run_model.py --config=yolo11m.yaml
# Out:
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# #### Yolo26n

# %%
# !python run_model.py --config=yolo26n.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# #### Yolo26s

# %%
# !python run_model.py --config=yolo26s.yaml
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# #### Yolo26m

# %%
# !python run_model.py --config=yolo26m.yaml
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# #### Yolo26l

# %%
# !python run_model.py --config=yolo26l.yaml
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# #### Yolo26x

# %%
# !python run_model.py --config=yolo26x.yaml
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.4.38 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo11m_1024.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.4.48 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %% [markdown]
# ### CBAM models with Transfer Learning

# %%
# !python run_model.py --config=yolo26n_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 240/711 items from pretrained weights
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26n_cbam_unfrozen.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 240/711 items from pretrained weights
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26s_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 41/711 items from pretrained weights
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26m_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 41/711 items from pretrained weights
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26l_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 41/711 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.4.67 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26l_p2_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 68/908 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.4.67 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26n_p2.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 360/902 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.4.63 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...

# %%
# !python run_model.py --config=yolo26n_p2_cbam.yaml
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Transferred 357/908 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.4.63 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.56 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 12227MiB)
# ...
